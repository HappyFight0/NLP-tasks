# %% [markdown]
# # Frequncy distribution

# %%
import nltk
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
text1 ="As the Messi family had relatives in Catalonia, they sought to arrange a trial with Barcelona in September 2000. First team director Charly Rexach immediately wanted to sign him, but the board of directors hesitated; at the time it was highly unusual for European clubs to sign foreign players of such a young age. On 14 December, an ultimatum was issued for Barcelona to prove their commitment, and Rexach, with no other paper at hand, offered a contract on a paper napkin.[18][21] In February 2001, the family relocated to Barcelona, where they moved into an apartment near the club's stadium, Camp Nou. During his first year in Spain, Messi rarely played with the Infantiles due to a transfer conflict with Newell's; as a foreigner, he could only be fielded in friendlies and the Catalan league. Without football, he struggled to integrate into the team; already reserved by nature, he was so quiet that his teammates initially believed he was mute. At home, he suffered from homesickness after his mother moved back to Rosario with his brothers and little sister, María Sol, while he stayed in Barcelona with his father." 
fd = nltk.FreqDist(text1.split())
fd
for val in fd:
    res= "{}: {}"
    print(res.format(val, fd[val]))
# Out:
# the: 8
# to: 8
# a: 6
# with: 6
# he: 6
# in: 5
# his: 5
# was: 4
# Barcelona: 3
# and: 3
# Messi: 2
# family: 2
# they: 2
# sign: 2
# of: 2
# at: 2
# for: 2
# an: 2
# paper: 2
# moved: 2
# into: 2
# As: 1
# had: 1
# relatives: 1
# Catalonia,: 1
# sought: 1
# arrange: 1
# trial: 1
# September: 1
# 2000.: 1
# First: 1
# team: 1
# director: 1
# Charly: 1
# Rexach: 1
# immediately: 1
# wanted: 1
# him,: 1
# but: 1
# board: 1
# directors: 1
# hesitated;: 1
# time: 1
# it: 1
# highly: 1
# unusual: 1
# European: 1
# clubs: 1
# foreign: 1
# players: 1
# such: 1
# young: 1
# age.: 1
# On: 1
# 14: 1
# December,: 1
# ultimatum: 1
# issued: 1
# prove: 1
# their: 1
# commitment,: 1
# Rexach,: 1
# no: 1
# other: 1
# hand,: 1
# offered: 1
# contract: 1
# on: 1
# napkin.[18][21]: 1
# In: 1
# February: 1
# 2001,: 1
# relocated: 1
# Barcelona,: 1
# where: 1
# apartment: 1
# near: 1
# club's: 1
# stadium,: 1
# Camp: 1
# Nou.: 1
# During: 1
# first: 1
# year: 1
# Spain,: 1
# rarely: 1
# played: 1
# ...

# %% [markdown]
# ## Conditional Frequency

# %%
from nltk.probability import ConditionalFreqDist

# %%
cfd = ConditionalFreqDist((len(word), word) for word in text1.split())
cfd[4]
# Out:
# FreqDist({'with': 6, 'they': 2, 'sign': 2, 'into': 2, 'team': 1, 'him,': 1, 'time': 1, 'such': 1, 'age.': 1, 'near': 1, ...})

# %% [markdown]
# ## Highest repeated words in presidential address of Biden

# %%
from nltk.corpus import inaugural

# %%
text = inaugural.words(fileids='2021-Biden.txt')
text
# Out:
# ['Chief', 'Justice', 'Roberts', ',', 'Vice', ...]

# %%
fdw = nltk.FreqDist(text)
for val in fdw:
    res= "{}: {}"
    print(res.format(val, fdw[val]))
# Out:
# ,: 230
# .: 155
# the: 109
# of: 82
# and: 80
# we: 70
# to: 63
# a: 45
# I: 44
# ': 43
# in: 43
# our: 41
# this: 35
# for: 31
# is: 29
# will: 26
# We: 25
# And: 25
# us: 24
# you: 24
# :: 23
# not: 23
# all: 23
# my: 22
# s: 22
# as: 22
# be: 22
# that: 21
# have: 21
# America: 20
# can: 19
# : 15
# one: 14
# Nation: 13
# do: 13
# on: 12
# with: 12
# are: 12
# democracy: 11
# has: 11
# who: 11
# me: 11
# those: 11
# Americans: 10
# but: 10
# their: 10
# by: 10
# ;: 10
# much: 10
# people: 9
# at: 9
# more: 9
# know: 9
# story: 9
# ": 9
# another: 9
# ?: 9
# been: 8
# American: 8
# must: 8
# today: 8
# it: 8
# President: 7
# history: 7
# days: 7
# through: 7
# so: 7
# t: 7
# unity: 7
# when: 7
# fellow: 6
# together: 6
# than: 6
# each: 6
# these: 6
# time: 6
# re: 6
# work: 6
# children: 6
# world: 6
# like: 6
# they: 6
# moment: 6
# stand: 6
# did: 6
# That: 6
# day: 5
# The: 5
# where: 5
# come: 5
# out: 5
# power: 5
# here: 5
# from: 5
# But: 5
# great: 5
# or: 5
# once: 5
# ...

# %% [markdown]
# ## Most repeated nouns in Biden's inaugural speech

# %%
tagged = nltk.pos_tag(text)
fdd = nltk.FreqDist(tagged)
word = []
con = []
for val in fdd:
    res= "{}: {}"
    if(val[1][:2] == "NN"):
        word.append(val[0])
        con.append(fdd[val])
        print(res.format(val, fdd[val]))
# Out:
# ('America', 'NNP'): 20
# ('democracy', 'NN'): 11
# ('Nation', 'NN'): 11
# ('Americans', 'NNPS'): 10
# ('people', 'NNS'): 9
# ('story', 'NN'): 9
# ('today', 'NN'): 8
# ('s', 'NN'): 8
# ('President', 'NNP'): 7
# ('history', 'NN'): 7
# ('days', 'NNS'): 7
# ('unity', 'NN'): 7
# ('\x80\x94', 'NNP'): 6
# ('time', 'NN'): 6
# ('children', 'NNS'): 6
# ('world', 'NN'): 6
# ('moment', 'NN'): 6
# ('day', 'NN'): 5
# ('power', 'NN'): 5
# ('\x80\x94', 'NN'): 5
# ('work', 'NN'): 5
# ('truth', 'NN'): 5
# ('cause', 'NN'): 4
# ('centuries', 'NNS'): 4
# ('strength', 'NN'): 4
# ('peace', 'NN'): 4
# ('virus', 'NN'): 4
# ('country', 'NN'): 4
# ('War', 'NNP'): 4
# ('justice', 'NN'): 4
# ('soul', 'NN'): 4
# ('things', 'NNS'): 4
# ('way', 'NN'): 4
# ('Vice', 'NNP'): 3
# ('hope', 'NN'): 3
# ('violence', 'NN'): 3
# ('God', 'NNP'): 3
# ('heart', 'NN'): 3
# ('night', 'NN'): 3
# ('"', 'NN'): 3
# ('war', 'NN'): 3
# ('jobs', 'NNS'): 3
# ('cry', 'NN'): 3
# ('future', 'NN'): 3
# ('American', 'NNP'): 3
# ...

# %%
nouns = pd.DataFrame({'Nouns': word, 'count':con})
nouns.head(10)
# Out:
#        Nouns  count
# 0    America     20
# 1  democracy     11
# 2     Nation     11
# 3  Americans     10
# 4     people      9
# 5      story      9
# 6      today      8
# 7          s      8
# 8  President      7
# 9    history      7

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
sns.barplot(nouns['Nouns'][:10], nouns['count'][:10])
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Nouns', ylabel='count'>

# %% [markdown]
# ## Chinese segmentation using jieba

# %%
pip install jieba
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import jieba
seg = jieba.cut("我们尝试在阅读课中引入篇章思想，既能使词汇学习生机勃勃，更重要的是还能实现对篇章主题信息的掌握和培养构造篇章的能力，达到语言学习的最终目的", cut_all = True)
print(" ".join(seg))
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\Admin\AppData\Local\Temp\jieba.cache
# Loading model cost 0.570 seconds.
# Prefix dict has been built successfully.
# 我们 尝试 在 阅读 阅读课 中 引入 篇章 思想 ， 既能 使 词汇 词汇学 学习 生机 生机勃勃 勃勃 ， 更 重要 的 是 还 能 实现 对 篇章 主题 信息 的 掌握 和 培养 构造 篇章 的 能力 ， 达到 语言 语言学 学习 的 最终 目的

# %% [markdown]
# ## Basic Text processing Pipeline

# %%
import nltk
sent = "Become an expert in NLP"
words = nltk.word_tokenize(sent)
print(words)
# Out:
# ['Become', 'an', 'expert', 'in', 'NLP']

# %% [markdown]
# ## Sentence tokenizer

# %%
import nltk
texts = ["As the Messi family had relatives in Catalonia, they sought to arrange a trial with Barcelona in September 2000. First team director Charly Rexach immediately wanted to sign him, but the board of directors hesitated; at the time it was highly unusual for European clubs to sign foreign players of such a young age. On 14 December, an ultimatum was issued for Barcelona to prove their commitment, and Rexach, with no other paper at hand, offered a contract on a paper napkin.[18][21] In February 2001, the family relocated to Barcelona, where they moved into an apartment near the club's stadium, Camp Nou. During his first year in Spain, Messi rarely played with the Infantiles due to a transfer conflict with Newell's; as a foreigner, he could only be fielded in friendlies and the Catalan league. Without football, he struggled to integrate into the team; already reserved by nature, he was so quiet that his teammates initially believed he was mute. At home, he suffered from homesickness after his mother moved back to Rosario with his brothers and little sister, María Sol, while he stayed in Barcelona with his father."]
for text in texts:
    sentences = nltk.sent_tokenize(text)
    for sentence in sentences:
        words = nltk.word_tokenize(sentence)
        print(words)
        print("-----------------------------------------------------------------------------------------------------------------------------")
        tagged = nltk.pos_tag(words)
        print(tagged)
        print("\n")
# Out:
# ['As', 'the', 'Messi', 'family', 'had', 'relatives', 'in', 'Catalonia', ',', 'they', 'sought', 'to', 'arrange', 'a', 'trial', 'with', 'Barcelona', 'in', 'September', '2000', '.']
# -----------------------------------------------------------------------------------------------------------------------------
# [('As', 'IN'), ('the', 'DT'), ('Messi', 'NNP'), ('family', 'NN'), ('had', 'VBD'), ('relatives', 'NNS'), ('in', 'IN'), ('Catalonia', 'NNP'), (',', ','), ('they', 'PRP'), ('sought', 'VBD'), ('to', 'TO'), ('arrange', 'VB'), ('a', 'DT'), ('trial', 'NN'), ('with', 'IN'), ('Barcelona', 'NNP'), ('in', 'IN'), ('September', 'NNP'), ('2000', 'CD'), ('.', '.')]
#
#
# ['First', 'team', 'director', 'Charly', 'Rexach', 'immediately', 'wanted', 'to', 'sign', 'him', ',', 'but', 'the', 'board', 'of', 'directors', 'hesitated', ';', 'at', 'the', 'time', 'it', 'was', 'highly', 'unusual', 'for', 'European', 'clubs', 'to', 'sign', 'foreign', 'players', 'of', 'such', 'a', 'young', 'age', '.']
# ...
